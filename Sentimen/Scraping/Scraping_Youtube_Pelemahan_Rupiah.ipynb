# %% [markdown]
# #Install Library

# %%
pip install youtube-comment-downloader
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.5/300.5 kB 5.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Import Library

# %%
import pandas as pd
from youtube_comment_downloader import YoutubeCommentDownloader
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# #Youtube

# %%
from numpy import common_type
downloader = YoutubeCommentDownloader()
url = "https://www.youtube.com/watch?v=2FPx1_CUzYQ"
comments = []
for comment in downloader.get_comments_from_url(url):
    comments.append(comment)
df_youtube = pd.DataFrame(comments)

# %%
df_youtube
# Out:
#                              cid  \
# 0     UgwWQwS5Eqgde_AA-kB4AaABAg
# 1     UgznNVmjCece3yEgqfd4AaABAg
# 2     Ugzem6z7b5T4H4ka2VB4AaABAg
# 3     UgzxME9GhG9xCQmCRFV4AaABAg
# 4     UgzPrzfZQ0cfUHxWNWt4AaABAg
# ...                          ...
# 9922  Ugze9-d0NIKEIECb9Y54AaABAg
# 9923  UgwQHxk_rKJH4kuiwcN4AaABAg
# 9924  UgwduKFYBD1g_4B76sh4AaABAg
# 9925  UgwuoRffMzFcriWqAQF4AaABAg
# 9926  UgzFEGrivmGLpZg0UHR4AaABAg
#
#                                                                                                       text  \
# 0                                                   hallo warga sipil sekalian semoga ini menjelaskan ya ❤
# 1                                                                               Rupiah melemah TKI bahagia
# 2     Wkwkw nyari data pembandingnya cuma yg bagus2, gak liat noh malaydesh pertumbuhan ekonominya berapa?
# 3                                                  Barang aman barang tambung habis d vili sama asing vivo
# ...

# %%
df_youtube = df_youtube[['text']].copy()

# %%
df_youtube.to_excel("pelemahan rupiah.xlsx", index=False)
